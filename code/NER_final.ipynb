# %% [markdown]
# # Load Data

# %%
! mkdir ../data
! cd ../data; wget https://raw.githubusercontent.com/leondz/emerging_entities_17/master/wnut17train.conll
! cd ../data; wget https://raw.githubusercontent.com/leondz/emerging_entities_17/master/emerging.test.annotated

# %%
wnut_path = "../data/wnut17train.conll"

# %%
test_path = "../data/emerging.test.annotated"

# %%
import pandas as pd
import csv
df = pd.read_csv(wnut_path,sep="\t")
df_test = pd.read_csv(test_path, header = None, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8',sep="\t")

# %%
labels
# Out:
# {'corporation', 'creative-work', 'group', 'location', 'person', 'product'}

# %% [markdown]
# ## Utility functions to construct dataset

# %%
import nltk
from nltk.tokenize import sent_tokenize 

def get_labels(dataframe):
    """Get all labels from a dataframe, is only applicable to the wnut2017 dataset"""
    labels = []
    for i,row in df.iterrows():
        if(row.O != 'O' and (not isinstance(row.O,float))):
            labels.append(row.O)
    labels = [x[2:len(x)] for x in labels]
    labels = set(labels)
    return labels

def read_file(path):
    """Reads a file line by line and returns a list where each entry corresponds to a line in the file
    
    Parameters
    ----------
    path: path of the file to read
    """
    with open(path) as f:
        content = f.readlines()
    return content

def read_file_and_split_lines(path):
    """
    Reads a file per line at a given path, replaces '\t' with " " and converts each line from 
    string to a list of words
    
    Parameters
    ----------
    path: path of the file to read
    """
    content = [x.replace("\t", " ") for x in read_file(path)]
    text = [x.split() for x in content]
    return text

def wnut_17_to_spacy_format(list_labels):
    """
    The Wnut-017 dataset is in B-I format we need to combine those entries to one single entry. 
    This function will do exactly this. 
    Example: 
    (14, 'B', 'location'), (15, 'I', 'location'), (16, 'I', 'location'), (18, 'B', 'location')
    Will be transformed to (14,16,location),(18,location)
    
    Parameters
    ----------
    list_labels: list of labels to transform
    """
    res = []
    for i,x in enumerate(list_labels):
        j = 1
        if(i + j< len(list_labels) and x[1] == 'B' and list_labels[i  + j][1] == 'I'):
            while(i + j < len(list_labels) and list_labels[i + j][1] == 'I'):
                j += 1
            res.append((x[0],x[0] + j -1 ,x[2]))
        elif(x[1] == 'B'):
            res.append([x[0],x[2]])
    return res

def str_i_to_char_i(sent_label):
    print(sent_label)
    """ Takes as arguments a sentence and a list of entities whith the corresponding indexes at word level, 
    and returns the same sentence combined with the indexes of the entities at character level. 
    
    Parameters
    ----------
    sent_label: sentence with entities at word level 
    
    """
    res_labels = []
    sent = sent_label[0].split()
    labels = sent_label[1]
    
    for label in labels: 
        if(len(label) == 2):
            start_label_index = label[0]
            end_label_index = label[0]
            label_name = label[1]
        elif(len(label) == 3):
            start_label_index = label[0]
            end_label_index = label[1]
            label_name = label[2]
        

        start_char_index = sum([len(x) for x in sent[0:start_label_index]])    
        end_char_index = start_char_index + sum([len(x) for x in sent[start_label_index:end_label_index + 1]])
        res_labels.append((start_char_index + start_label_index,end_char_index + end_label_index,label_name))
        
    res = [" ".join(sent), res_labels]
    print(res)
    return 

def to_spacy_format(sent_label): 
    """Takes as arguments a sentence and a list of entities, creates a dict with a single entry: the entities.
    returns a list of the sentence and the created"""
    sent = sent_label[0]
    labels = sent_label[1]
    res_dict = {'entities': labels}
    return [sent, res_dict]

def create_entities_char_level(text):
    res = []
    sentence = []
    sent_labels = []
    for word_entity_pair in text:
        if(len(word_entity_pair)!=0):
            sentence.append(word_entity_pair[0])
            sent_labels.append(word_entity_pair[1])
        else:
            sent_labels = [(i,x[0], x[2:len(x)]) for i,x in enumerate(sent_labels) if x != 'O' ]
            sent_labels = wnut_17_to_spacy_format(sent_labels)
            res.append([" ".join(sentence),sent_labels])
            sent_labels = []
            sentence = []
        
    res = [str_i_to_char_i(x) for x in res]
    res = [to_spacy_format(x) for x in res]
    return res

# %% [markdown]
# Show which entitities we are going to predict

# %%
labels = get_labels(df)
labels

# %% [markdown]
# Stats about the dataset

# %%
from collections import defaultdict 
dict_labels = defaultdict(int)
for x in EVAL_DATA:
    entitites = x[1]['entities']
    for y in entitites: 
        label = y[2]
        dict_labels[label] += 1
dict_labels
# Out:
# defaultdict(int,
#             {'location': 150,
#              'group': 165,
#              'person': 429,
#              'creative-work': 142,
#              'corporation': 66,
#              'product': 127})

# %%
text_train = read_file_and_split_lines(wnut_path)
text_test = read_file_and_split_lines(test_path)

# %%
TRAIN_DATA = create_entities_char_level(text_train)
EVAL_DATA = create_entities_char_level(text_test)
# Out:
# ["@paulwalk It 's the view from where I 'm living for two weeks . Empire State Building = ESB . Pretty bad storm here last evening .", [(14, 16, 'location'), [18, 'location']]]
# ["@paulwalk It 's the view from where I 'm living for two weeks . Empire State Building = ESB . Pretty bad storm here last evening .", [(64, 85, 'location'), (88, 91, 'location')]]
# ['From Green Newsfeed : AHFA extends deadline for Sage Award to Nov . 5 http://tinyurl.com/24agj38', [[4, 'group']]]
# ['From Green Newsfeed : AHFA extends deadline for Sage Award to Nov . 5 http://tinyurl.com/24agj38', [(22, 26, 'group')]]
# ['Pxleyes Top 50 Photography Contest Pictures of August 2010 ... http://bit.ly/bgCyZ0 #photography', [[0, 'corporation']]]
# ['Pxleyes Top 50 Photography Contest Pictures of August 2010 ... http://bit.ly/bgCyZ0 #photography', [(0, 7, 'corporation')]]
# ['today is my last day at the office .', []]
# ['today is my last day at the office .', []]
# ["4Dbling 's place til monday , party party party . &lt; 3", [[0, 'person']]]
# ["4Dbling 's place til monday , party party party . &lt; 3", [(0, 7, 'person')]]
# ["watching the VMA pre-show again lol it was n't even a good show the first time ... so bored !", [[2, 'creative-work']]]
# ["watching the VMA pre-show again lol it was n't even a good show the first time ... so bored !", [(13, 16, 'creative-work')]]
# ['27 followers ! 30 followers is my goal for today !', []]
# ['27 followers ! 30 followers is my goal for today !', []]
# ["This is the 2nd hospital ive been in today , but ive just seen a doctor who was an older version of justin :' )", []]
# ["This is the 2nd hospital ive been in today , but ive just seen a doctor who was an older version of justin :' )", []]
# ['Friday Night Eats http://twitpic.com/2pdvtr', []]
# ['Friday Night Eats http://twitpic.com/2pdvtr', []]
# ['Gotta dress up for london fashion week and party in style !', []]
# ['Gotta dress up for london fashion week and party in style !', []]
# ["@Suzie55 whispering cause I may have had 1 too many vodka 's last night and am a lil fragile , hold me ?", [[10, 'product']]]
# ["@Suzie55 whispering cause I may have had 1 too many vodka 's last night and am a lil fragile , hold me ?", [(52, 57, 'product')]]
# ['#NFL Week 2 picks blog is up on @The_Score website ... http://blogs.thescore.com/nfl/2010/09/17/pizzolaw2/', []]
# ['#NFL Week 2 picks blog is up on @The_Score website ... http://blogs.thescore.com/nfl/2010/09/17/pizzolaw2/', []]
# ['I like @SouljaBoy songs after a few drinks', []]
# ['I like @SouljaBoy songs after a few drinks', []]
# ['... asked me a question for once , but no ! You ask me about fucking donuts you donut ... have a nice day :P', []]
# ['... asked me a question for once , but no ! You ask me about fucking donuts you donut ... have a nice day :P', []]
# ['every year your " bestfriend " get yo ass in trouble smdh #doinme', []]
# ['every year your " bestfriend " get yo ass in trouble smdh #doinme', []]
# ["RT @midgetmegs : hate people who write drunk status'. must be having a great time if your sat writing it on facebook .....", [[21, 'corporation']]]
# ["RT @midgetmegs : hate people who write drunk status'. must be having a great time if your sat writing it on facebook .....", [(108, 116, 'corporation')]]
# ["@MrzEndy tru tru I 'm leavin again on Tuesday yo", []]
# ["@MrzEndy tru tru I 'm leavin again on Tuesday yo", []]
# ['The guys are cooking about a dozen pizzas at our house for the tailgate tonight . Nonetheless it smells fresh in this place .', []]
# ['The guys are cooking about a dozen pizzas at our house for the tailgate tonight . Nonetheless it smells fresh in this place .', []]
# ['I heart Park(ing ) Day ! Photo of meter shark : http://bit.ly/aQun1b', []]
# ['I heart Park(ing ) Day ! Photo of meter shark : http://bit.ly/aQun1b', []]
# ['hows everyones day goin ?', []]
# ['hows everyones day goin ?', []]
# ['@Phoebe1_ and i also loved the last years eurovision entry !! hoppaa ! they were cool too !!', []]
# ['@Phoebe1_ and i also loved the last years eurovision entry !! hoppaa ! they were cool too !!', []]
# ["MetroPCS has the worst customer service I 've experienced in months ( trying to help someone order a phone ) #metropcs #fail", [[0, 'corporation']]]
# ["MetroPCS has the worst customer service I 've experienced in months ( trying to help someone order a phone ) #metropcs #fail", [(0, 8, 'corporation')]]
# ['@xSophieBx He has a habit of tweeting at the same time as you lol', []]
# ['@xSophieBx He has a habit of tweeting at the same time as you lol', []]
# ['A TRUE friend walks in when everybody else walks out !', []]
# ['A TRUE friend walks in when everybody else walks out !', []]
# ['Yay . @penguin is coming to see me next week ... plotting my cooking now !', []]
# ['Yay . @penguin is coming to see me next week ... plotting my cooking now !', []]
# ['@_mistercory *Smiles up at him* Can we just ... sit together for a while before round two ?', []]
# ['@_mistercory *Smiles up at him* Can we just ... sit together for a while before round two ?', []]
# ['the tears may have been and gone , but the feeling still stay the same .', []]
# ['the tears may have been and gone , but the feeling still stay the same .', []]
# ["@BieberEgypt I 've got some bad news , Yeah I cant come to the meeting tomorrow . : S", []]
# ["@BieberEgypt I 've got some bad news , Yeah I cant come to the meeting tomorrow . : S", []]
# ["@abzmedic I 'm missing autumn because of work . :( I must get into the forests tomorrow !", []]
# ["@abzmedic I 'm missing autumn because of work . :( I must get into the forests tomorrow !", []]
# ["Fellas Do n't just lick the PussyY , LOVE IT ! enjoy it . like u just got married &lt; the preacher said u may kiss the bride", []]
# ["Fellas Do n't just lick the PussyY , LOVE IT ! enjoy it . like u just got married &lt; the preacher said u may kiss the bride", []]
# ['RT @Sexstrology : Pisces tend to escape into fantasy and day dreams . There they are free .', []]
# ['RT @Sexstrology : Pisces tend to escape into fantasy and day dreams . There they are free .', []]
# ['Cant wait for the ravens game tomorrow .... go ray rice !!!!!!!', [[4, 'group'], (9, 10, 'person')]]
# ['Cant wait for the ravens game tomorrow .... go ray rice !!!!!!!', [(18, 24, 'group'), (47, 55, 'person')]]
# ['I just took " When your mom makes you go live with your dad Scooter Braun , your life ..." and got : Part 7 ! Try it : http://tinyurl.com/27r2pdz', [(14, 15, 'person')]]
# ['I just took " When your mom makes you go live with your dad Scooter Braun , your life ..." and got : Part 7 ! Try it : http://tinyurl.com/27r2pdz', [(60, 73, 'person')]]
# ['I miss being able to run and dance around all day instead of having to catch my breath every five minutes of my life .', []]
# ['I miss being able to run and dance around all day instead of having to catch my breath every five minutes of my life .', []]
# ['@SnoopDogg hey snoop my wife Cath is 30 today , any chance of a shout out to her ,', [[2, 'person']]]
# ['@SnoopDogg hey snoop my wife Cath is 30 today , any chance of a shout out to her ,', [(15, 20, 'person')]]
# ["Today I got a promotion at work , and tomorrow I 'm going home to Wisconsin for a few days . So content with life right now . :)", [[15, 'location']]]
# ["Today I got a promotion at work , and tomorrow I 'm going home to Wisconsin for a few days . So content with life right now . :)", [(66, 75, 'location')]]
# ['TWEET ! @stjosephs Empls of the Month : Deborah L #Speech #Pathologist-Childrens Rehab and Patricia M #Referral/#Auth #Spec-#Womens #Care !', [(8, 9, 'person'), (14, 15, 'person')]]
# ['TWEET ! @stjosephs Empls of the Month : Deborah L #Speech #Pathologist-Childrens Rehab and Patricia M #Referral/#Auth #Spec-#Womens #Care !', [(40, 49, 'person'), (91, 101, 'person')]]
# ['RT @LilTwist : RT this if you want me to go back live on Ustream later tonight', [[14, 'corporation']]]
# ['RT @LilTwist : RT this if you want me to go back live on Ustream later tonight', [(57, 64, 'corporation')]]
# ["Really hope I can get to @glasgowfilm for Winter 's Bone - need to get on with job applications tonight then ! Trailer : http://bit.ly/bhUlum", [(8, 10, 'creative-work')]]
# ["Really hope I can get to @glasgowfilm for Winter 's Bone - need to get on with job applications tonight then ! Trailer : http://bit.ly/bhUlum", [(42, 56, 'creative-work')]]
# ['RT @WeSpazForJB : http://twitpic.com/2nn4ee &lt; ---- still the funniest photo . of all time . ALL TIME .', []]
# ['RT @WeSpazForJB : http://twitpic.com/2nn4ee &lt; ---- still the funniest photo . of all time . ALL TIME .', []]
# ['I have eaten a large quantity of oranges this week ...', []]
# ['I have eaten a large quantity of oranges this week ...', []]
# ['Bonfire tonite . All are welcome , joe included', [[7, 'person']]]
# ['Bonfire tonite . All are welcome , joe included', [(35, 38, 'person')]]
# ['@KFSH totally ! I can go a week w/o tv , phones or a computer . I get some time to myself and God . Brings peace into my life .', [[23, 'person']]]
# ['@KFSH totally ! I can go a week w/o tv , phones or a computer . I get some time to myself and God . Brings peace into my life .', [(94, 97, 'person')]]
# ["i want a bath but do n't have a bath , shut up , sam 's coming tomorrow and steve and tanya will be round at 10am so go away you mean people", [[14, 'person'], [19, 'person'], [21, 'person']]]
# ["i want a bath but do n't have a bath , shut up , sam 's coming tomorrow and steve and tanya will be round at 10am so go away you mean people", [(49, 52, 'person'), (76, 81, 'person'), (86, 91, 'person')]]
# ['What Do S.F. Rabbis Eat Before and After Yom Kippur ? We Asked Five to Enlighten Us ! via @SFoodie http://bit.ly/aQrFUz', [[2, 'location']]]
# ['What Do S.F. Rabbis Eat Before and After Yom Kippur ? We Asked Five to Enlighten Us ! via @SFoodie http://bit.ly/aQrFUz', [(8, 12, 'location')]]
# ["Not only is it #BattlestarGalactica 's 32nd Anniversary , tonite is the 3rd season premiere of #StarWars #TheCloneWars !!", [[4, 'creative-work'], (16, 17, 'creative-work')]]
# ["Not only is it #BattlestarGalactica 's 32nd Anniversary , tonite is the 3rd season premiere of #StarWars #TheCloneWars !!", [(15, 35, 'creative-work'), (95, 118, 'creative-work')]]
# ["just about off work ! going to alderwood again :) yay . hopefully we got cody 's ipod in the mail today .", [[7, 'location'], [17, 'product']]]
# ["just about off work ! going to alderwood again :) yay . hopefully we got cody 's ipod in the mail today .", [(31, 40, 'location'), (81, 85, 'product')]]
# ['RT @Slijterijmeisje : Kreeg net een bruikbare tip van iemand die vorige week was begonnen met een whiskydieet , hij was nu al 3 dagen kwijt', []]
# ['RT @Slijterijmeisje : Kreeg net een bruikbare tip van iemand die vorige week was begonnen met een whiskydieet , hij was nu al 3 dagen kwijt', []]
# ["Its stupid I hate getn a attitude from ppl when I 'm jus tryna be nice n shit . WTF now I 'm mad so dnt talk to me right now", []]
# ["Its stupid I hate getn a attitude from ppl when I 'm jus tryna be nice n shit . WTF now I 'm mad so dnt talk to me right now", []]
# ['RT @DamnTeenQuotes : I remember when i was your age , spencer from iCarly was Crazy Steve , Carly was Megan and Josh was fat . #damnteenquotes', [[11, 'person'], [13, 'creative-work'], (15, 16, 'person'), [18, 'person'], [20, 'person'], [22, 'person']]]
# ['RT @DamnTeenQuotes : I remember when i was your age , spencer from iCarly was Crazy Steve , Carly was Megan and Josh was fat . #damnteenquotes', [(54, 61, 'person'), (67, 73, 'creative-work'), (78, 89, 'person'), (92, 97, 'person'), (102, 107, 'person'), (112, 116, 'person')]]
# ['Last stop of the day thank goddddd (@ H-E-B Plus ) http://4sq.com/7RDhgd', []]
# ['Last stop of the day thank goddddd (@ H-E-B Plus ) http://4sq.com/7RDhgd', []]
# ["@itzkeving im getting mine off this monday :' )", []]
# ["@itzkeving im getting mine off this monday :' )", []]
# ['#Fancyflow .. im in the hair salon right now .. smh .. Friday , its packed in here RT @neimanMarcus203 : Where is @ihavesuperpower ???', []]
# ['#Fancyflow .. im in the hair salon right now .. smh .. Friday , its packed in here RT @neimanMarcus203 : Where is @ihavesuperpower ???', []]
# ["@vogueglamGIRL Ah I know ! She is simply the best in The Sept Issue . My boyfriend 's aunt worked for Anna Wintor in NY .", [(21, 22, 'person')]]
# ["@vogueglamGIRL Ah I know ! She is simply the best in The Sept Issue . My boyfriend 's aunt worked for Anna Wintor in NY .", [(102, 113, 'person')]]
# ['You gotta let em lick it before they stick it', []]
# ['You gotta let em lick it before they stick it', []]
# ["There 's a lot of people showing off their iPhones on facebook today , so &lt; so is at such a place , it 's really not that interesting ;o )", [[9, 'product'], [11, 'corporation']]]
# ["There 's a lot of people showing off their iPhones on facebook today , so &lt; so is at such a place , it 's really not that interesting ;o )", [(43, 50, 'product'), (54, 62, 'corporation')]]
# ['@Infamous__Kid lol you always got problems with ur hair you said somethin last time like they didnt cut it right ha', []]
# ['@Infamous__Kid lol you always got problems with ur hair you said somethin last time like they didnt cut it right ha', []]
# ["For code I 've written since Sept ' 09 , the delay between commit to SCM and running on customer hardware has been about 10 days .", []]
# ["For code I 've written since Sept ' 09 , the delay between commit to SCM and running on customer hardware has been about 10 days .", []]
# ['AND EVERYTHING YOU STAND FOR , TURNS ON YOU TO SPITE YOU ? WHAT HAPPENS WHEN YOU BECOME THE MAIN SOURCE OF HER PAIN ?', []]
# ['AND EVERYTHING YOU STAND FOR , TURNS ON YOU TO SPITE YOU ? WHAT HAPPENS WHEN YOU BECOME THE MAIN SOURCE OF HER PAIN ?', []]
# ["Yo kids ! Today 's ACF Friday Large Group is at PITT University ! It 's at Cathedral of Learning G24 at 7pm ! Be sure to check it out !", [(11, 12, 'location'), (17, 20, 'location')]]
# ["Yo kids ! Today 's ACF Friday Large Group is at PITT University ! It 's at Cathedral of Learning G24 at 7pm ! Be sure to check it out !", [(48, 63, 'location'), (75, 100, 'location')]]
# ['RT @WALuvsKatStacks : Ah , i asked for a follow back - when i already hadd one so they call me thirsty lmao ? Fck you #teamkatstacksbitch ...', []]
# ['RT @WALuvsKatStacks : Ah , i asked for a follow back - when i already hadd one so they call me thirsty lmao ? Fck you #teamkatstacksbitch ...', []]
# [':( RT @themaine Who is coming to the show tomorrow in Hawaii ?', [[11, 'location']]]
# [':( RT @themaine Who is coming to the show tomorrow in Hawaii ?', [(54, 60, 'location')]]
# ['chinese food .. stayin in for tonight but goin to the archery range either tomorrow or sunday', []]
# ['chinese food .. stayin in for tonight but goin to the archery range either tomorrow or sunday', []]
# ['@Strigy got mine in bbt aintree today . Played table tennis on it in store ! V impressed . Did you get analogue controller 2 ?', [[5, 'location']]]
# ['@Strigy got mine in bbt aintree today . Played table tennis on it in store ! V impressed . Did you get analogue controller 2 ?', [(24, 31, 'location')]]
# ['RT @Luq_Combs : Funniest thing I heard this week . Wingo tellin me and wood . " I \'m scared " #pow#pow#pow@Cowboy_Wingo', [[10, 'person']]]
# ['RT @Luq_Combs : Funniest thing I heard this week . Wingo tellin me and wood . " I \'m scared " #pow#pow#pow@Cowboy_Wingo', [(51, 56, 'person')]]
# ["Today 's cheer went from awful to awesome from the moment I realized I did not have class today .", []]
# ["Today 's cheer went from awful to awesome from the moment I realized I did not have class today .", []]
# ['Time Warner Cable Boycotting Epix Movie Channel Because It Did A Deal With Netflix http://dlvr.it/5RgcL', [(0, 2, 'corporation'), [13, 'corporation']]]
# ['Time Warner Cable Boycotting Epix Movie Channel Because It Did A Deal With Netflix http://dlvr.it/5RgcL', [(0, 17, 'corporation'), (75, 82, 'corporation')]]
# ['Fresh out the psych ward today', []]
# ['Fresh out the psych ward today', []]
# ['Today was awesome , I finally get to relax :)', []]
# ['Today was awesome , I finally get to relax :)', []]
# ['My #twitter age is 458 days 0 hours 3 minutes 49 seconds . Find out yours at http://twitter.seocoder.org/ #twittertime', []]
# ['My #twitter age is 458 days 0 hours 3 minutes 49 seconds . Find out yours at http://twitter.seocoder.org/ #twittertime', []]
# ["What is it with people and punctuality ? I used to be that guy and honestly , it 's a haze now . Just be on time . It 's not like its a surprise .", []]
# ["What is it with people and punctuality ? I used to be that guy and honestly , it 's a haze now . Just be on time . It 's not like its a surprise .", []]
# ['After I pet a kitten on JFK , the owners informed me it \'s \' double-pawed \' ( polydactyl) , which is " a form of retardation in the animal kingdom "', [[6, 'person']]]
# ['After I pet a kitten on JFK , the owners informed me it \'s \' double-pawed \' ( polydactyl) , which is " a form of retardation in the animal kingdom "', [(24, 27, 'person')]]
# ['Soulja Boy | TheDeAndreWay . com - The DeAndre Way in stores Nov . 2 , 2010 http://t.co/woAiLlZ via @SouljaBoy', [(0, 1, 'person')]]
# ['Soulja Boy | TheDeAndreWay . com - The DeAndre Way in stores Nov . 2 , 2010 http://t.co/woAiLlZ via @SouljaBoy', [(0, 10, 'person')]]
# ['About online dietician : A thinner stool than usual can be identified and removed before they get are 2 weeks ago J ... http://bit.ly/cYGBdz', []]
# ['About online dietician : A thinner stool than usual can be identified and removed before they get are 2 weeks ago J ... http://bit.ly/cYGBdz', []]
# ['RT @RMBWilliams : Here in DC ! About to get some rest ! Looking forward to tonight ! Yes-sir !', [[5, 'location']]]
# ['RT @RMBWilliams : Here in DC ! About to get some rest ! Looking forward to tonight ! Yes-sir !', [(26, 28, 'location')]]
# ["RT @twitter : #AskEv your big questions about the new Twitter . com today at 1pm PST . 'll be responding from his own account (@ev) . Make ...", [[10, 'corporation']]]
# ["RT @twitter : #AskEv your big questions about the new Twitter . com today at 1pm PST . 'll be responding from his own account (@ev) . Make ...", [(54, 61, 'corporation')]]
# ['I need a syringe of anything you want but which will switch me off till tomorrow noon , anyone ??', []]
# ['I need a syringe of anything you want but which will switch me off till tomorrow noon , anyone ??', []]
# ['RT @high_n_fly : #FACT when you are comfortable with yourself nothing else matters nobody can tell you about yourself #HnF', []]
# ['RT @high_n_fly : #FACT when you are comfortable with yourself nothing else matters nobody can tell you about yourself #HnF', []]
# ["Lindsay Lohan allegedly failed her drug test . So not fetch . Quick , let 's all put on our shocked faces that 23 days of rehab did n't work !", [(0, 1, 'person')]]
# ["Lindsay Lohan allegedly failed her drug test . So not fetch . Quick , let 's all put on our shocked faces that 23 days of rehab did n't work !", [(0, 13, 'person')]]
# ['I remember when you all were thiiis big , you know ?', []]
# ['I remember when you all were thiiis big , you know ?', []]
# ['I have a strong hunch Adam will be a story on TMZ tonight . Gulp .', [[5, 'person'], [11, 'creative-work']]]
# ['I have a strong hunch Adam will be a story on TMZ tonight . Gulp .', [(22, 26, 'person'), (46, 49, 'creative-work')]]
# ['WEDNESDAY NITES WE CRANK IT UP AT VISIONS LOUNGE !!!!! 18+ NO COLLEGE ID NEEDED ! LADIES FREE B4 11PM ! VISIONS LOUNGE ( 247 1ST AVE HKY )', [(7, 8, 'location'), (21, 22, 'location')]]
# ['WEDNESDAY NITES WE CRANK IT UP AT VISIONS LOUNGE !!!!! 18+ NO COLLEGE ID NEEDED ! LADIES FREE B4 11PM ! VISIONS LOUNGE ( 247 1ST AVE HKY )', [(34, 48, 'location'), (104, 118, 'location')]]
# ['@angelportugues LMAO ! When is tht one day ?: P', []]
# ['@angelportugues LMAO ! When is tht one day ?: P', []]
# ['RT @PLLGirls : Episodes 1-10 of Pretty Little Liars will air in the UK on October 18 !', [(6, 8, 'creative-work'), [13, 'location']]]
# ['RT @PLLGirls : Episodes 1-10 of Pretty Little Liars will air in the UK on October 18 !', [(32, 51, 'creative-work'), (68, 70, 'location')]]
# ['@Loserface_Laura when mike lets me know , I will let you know . I mean everyone might just switch out a lot .', [[2, 'person']]]
# ['@Loserface_Laura when mike lets me know , I will let you know . I mean everyone might just switch out a lot .', [(22, 26, 'person')]]
# ['Such a shiny morning !!! Love It . Anyways , today will be very busy !', []]
# ['Such a shiny morning !!! Love It . Anyways , today will be very busy !', []]
# ['@BornThisWayBaby thankk yhuu #monsterlove u just made my day :D', []]
# ['@BornThisWayBaby thankk yhuu #monsterlove u just made my day :D', []]
# ['Why hate on somebody for doing well when you can simply say great job and move on .. [Haters u can kill yourself ] cuz ur losers', []]
# ['Why hate on somebody for doing well when you can simply say great job and move on .. [Haters u can kill yourself ] cuz ur losers', []]
# ['If you are staying in Gainesville , come check out Costa Lounge TONIGHT ! Say you are with salsa caliente and get in ... http://fb.me/FZVzm8H9', [[5, 'location'], (10, 11, 'location'), (18, 19, 'person')]]
# ['If you are staying in Gainesville , come check out Costa Lounge TONIGHT ! Say you are with salsa caliente and get in ... http://fb.me/FZVzm8H9', [(22, 33, 'location'), (51, 63, 'location'), (91, 105, 'person')]]
# ['@jackjohnson where can I get the official set list to the show at Berkeley in Oct 6th ?!', [[13, 'location']]]
# ['@jackjohnson where can I get the official set list to the show at Berkeley in Oct 6th ?!', [(66, 74, 'location')]]
# ['Check this video out -- Three Days Grace - Break ( Official Music Video ) [ HQ ] http://t.co/GOwCLQJ via @youtube', [(5, 7, 'group')]]
# ['Check this video out -- Three Days Grace - Break ( Official Music Video ) [ HQ ] http://t.co/GOwCLQJ via @youtube', [(24, 40, 'group')]]
# ['Haha I seen a ped egg called a foot cheese grater today . I found it proper hilarious xD', []]
# ['Haha I seen a ped egg called a foot cheese grater today . I found it proper hilarious xD', []]
# ['friday night missions iguess !', []]
# ['friday night missions iguess !', []]
# ["Just got home from school . :D it 's friday guys !,", []]
# ["Just got home from school . :D it 's friday guys !,", []]
# ['@ohy22SD Hopefully the Force will be VERY strong with the #Padres tonight . We NEED a win . #ScoreSomeRuns', [[10, 'group']]]
# ['@ohy22SD Hopefully the Force will be VERY strong with the #Padres tonight . We NEED a win . #ScoreSomeRuns', [(58, 65, 'group')]]
# ['" before we start , how old are you ? HER : I \'m 15 .. old enough !........ #FindTheNearestExit', []]
# ['" before we start , how old are you ? HER : I \'m 15 .. old enough !........ #FindTheNearestExit', []]
# ['RT @ericjohnsalut " Good Morning ! Have a pleasant and happy day !" http://dlvr.it/5Rh4w', []]
# ['RT @ericjohnsalut " Good Morning ! Have a pleasant and happy day !" http://dlvr.it/5Rh4w', []]
# ['when did @thecodysimpson last tweet ,? ;)', []]
# ['when did @thecodysimpson last tweet ,? ;)', []]
# ['@JoshRamsayArmy Kay sorry ... Well my dad lest when i was 3 . He has issues . He held a knife at mom . I can STILL remember that ... =/', []]
# ['@JoshRamsayArmy Kay sorry ... Well my dad lest when i was 3 . He has issues . He held a knife at mom . I can STILL remember that ... =/', []]
# ["OH : Power nap . I need it . Its been a stressful week . I'm excited for xmas , haha . Goodnight . :) http://bit.ly/9fQGkC", []]
# ["OH : Power nap . I need it . Its been a stressful week . I'm excited for xmas , haha . Goodnight . :) http://bit.ly/9fQGkC", []]
# ['Wow .. saw pictures of Robert .... spent 2 1/2 years with him . Broke up 4 months ago &amp; I miss when we were perfect ..', [[5, 'person']]]
# ['Wow .. saw pictures of Robert .... spent 2 1/2 years with him . Broke up 4 months ago &amp; I miss when we were perfect ..', [(23, 29, 'person')]]
# ["RT @rockerfuckerak : What 's done is done , Just leave it alone , and don't regret . Sometimes somethings turn in-to dumb things . And that 's when ...", []]
# ["RT @rockerfuckerak : What 's done is done , Just leave it alone , and don't regret . Sometimes somethings turn in-to dumb things . And that 's when ...", []]
# ["@N4T4YLOR he'll probaly have something completely different now ! Hope your havin a good time", []]
# ["@N4T4YLOR he'll probaly have something completely different now ! Hope your havin a good time", []]
# ['We are one step closer to our new kitchens . We chose a maker and had official measurements taken today !', []]
# ['We are one step closer to our new kitchens . We chose a maker and had official measurements taken today !', []]
# ['@lofolulu RT @couponprincess : Please vote for me to be a Deal Pro in Chicago in November ! TY http://bit.ly/cgmnoX - DO WHAT @LOFOLULU SAYS !', [[14, 'location']]]
# ['@lofolulu RT @couponprincess : Please vote for me to be a Deal Pro in Chicago in November ! TY http://bit.ly/cgmnoX - DO WHAT @LOFOLULU SAYS !', [(70, 77, 'location')]]
# ['@zeeDOTi i might join in if I make it home in time . :)', []]
# ['@zeeDOTi i might join in if I make it home in time . :)', []]
# ["@DanaTennille that 's wazzup . congrats on your win in week 1 .", []]
# ["@DanaTennille that 's wazzup . congrats on your win in week 1 .", []]
# ["@Terrysagirl love to , it 's iffy though , i don't wanna give up privacy for the guys . But after episode one , they should be on imdb ;)", []]
# ["@Terrysagirl love to , it 's iffy though , i don't wanna give up privacy for the guys . But after episode one , they should be on imdb ;)", []]
# ['One day the things i say and do is gonna get me a nice slap ..', []]
# ['One day the things i say and do is gonna get me a nice slap ..', []]
# ['Shows Tonight-Local Natives @TheMusicBoxLA , Primus @ClubNokia Marina&amp;Diamonds @ElReyTheatre , Mystery Jets @TheTroubadour ( via @TheScenestar )', [[2, 'group'], [5, 'group'], (10, 11, 'group')]]
# ['Shows Tonight-Local Natives @TheMusicBoxLA , Primus @ClubNokia Marina&amp;Diamonds @ElReyTheatre , Mystery Jets @TheTroubadour ( via @TheScenestar )', [(20, 27, 'group'), (45, 51, 'group'), (99, 111, 'group')]]
# ['@geek @borkware Somehow my iPad in Airplane mode with WiFi off has no problem connecting to internet . Time for a wipe or downgrade .', [[4, 'product']]]
# ['@geek @borkware Somehow my iPad in Airplane mode with WiFi off has no problem connecting to internet . Time for a wipe or downgrade .', [(27, 31, 'product')]]
# ['Just listened to a 24 y/o kid from japan who won the national flat picking championship flipping amazing r/l august rush', [[8, 'location']]]
# ['Just listened to a 24 y/o kid from japan who won the national flat picking championship flipping amazing r/l august rush', [(35, 40, 'location')]]
# ['Pxleyes Top 50 Photography Contest Pictures of August 2010 ... http://bit.ly/bgCyZ0 #photography', []]
# ['Pxleyes Top 50 Photography Contest Pictures of August 2010 ... http://bit.ly/bgCyZ0 #photography', []]
# ['RT @ravenalexis Wanna meet me , @jessejane , @rileysteele , and @kayden_kross ? Come to the Body Heat signing at Hustler Hollywood Sep 23rd 8-10pm', [[1, 'person'], [6, 'person'], [8, 'person'], [11, 'person'], (16, 17, 'creative-work'), (20, 21, 'location')]]
# ['RT @ravenalexis Wanna meet me , @jessejane , @rileysteele , and @kayden_kross ? Come to the Body Heat signing at Hustler Hollywood Sep 23rd 8-10pm', [(3, 15, 'person'), (32, 42, 'person'), (45, 57, 'person'), (64, 77, 'person'), (92, 101, 'creative-work'), (113, 130, 'location')]]
# ['Aggressive Kids With ADHD May Not Need Antipsychotic Meds http://t.co/JfGm0uH', []]
# ['Aggressive Kids With ADHD May Not Need Antipsychotic Meds http://t.co/JfGm0uH', []]
# ['@KisssMyASS_ when ya birthday', []]
# ['@KisssMyASS_ when ya birthday', []]
# ['RT @WakaFlocka1017 : SO WHEN I GET ON 106 N JOKE AROUND YALL TALK ABOUT ME LIKE A DOG SHAWTY BUT WHEN I BUY 30,000 WORTH SCHOOL SUPPLY N ...', []]
# ['RT @WakaFlocka1017 : SO WHEN I GET ON 106 N JOKE AROUND YALL TALK ABOUT ME LIKE A DOG SHAWTY BUT WHEN I BUY 30,000 WORTH SCHOOL SUPPLY N ...', []]
# ["I won an election today . It means I get to go to head office and have lots of meetings . It shall be tough but I'm looking forward to it .", []]
# ["I won an election today . It means I get to go to head office and have lots of meetings . It shall be tough but I'm looking forward to it .", []]
# ['@TobyHymer you whittier kids have been on a public bus before :o ? Haha jk !', []]
# ['@TobyHymer you whittier kids have been on a public bus before :o ? Haha jk !', []]
# ['Ciroc it is dnt have a move tonite but imma make 1', []]
# ['Ciroc it is dnt have a move tonite but imma make 1', []]
# ['Ima start going to the dr once a month so I get my moneys worth', []]
# ['Ima start going to the dr once a month so I get my moneys worth', []]
# ['Toy story 3 tonight on the lawn !', [(0, 2, 'creative-work')]]
# ['Toy story 3 tonight on the lawn !', [(0, 11, 'creative-work')]]
# ['The EYE of the Storm .... The Calm Before It ...', []]
# ['The EYE of the Storm .... The Calm Before It ...', []]
# ['waiting one extra day was a STUPID IDEA because now everything is super expensive AAAAAHHH . x_x *freakingoutkhsf*', []]
# ['waiting one extra day was a STUPID IDEA because now everything is super expensive AAAAAHHH . x_x *freakingoutkhsf*', []]
# ['My dad is laughing because in some translations Mark 14:30 says : "... Before the COCK crows ...". I\'ve never been so proud LOL', [[8, 'person']]]
# ['My dad is laughing because in some translations Mark 14:30 says : "... Before the COCK crows ...". I\'ve never been so proud LOL', [(48, 52, 'person')]]
# ['@DrHubaEvaluator Not long ago I responded to a angry cardiologist whom I have known yrs . when he spit venom to the newspaper but I did it +', []]
# ['@DrHubaEvaluator Not long ago I responded to a angry cardiologist whom I have known yrs . when he spit venom to the newspaper but I did it +', []]
# ["Soo Glad its Finally Friday ! Thiss week went to slow fo'me:/", []]
# ["Soo Glad its Finally Friday ! Thiss week went to slow fo'me:/", []]
# ['Movies Tonight ? ( :', []]
# ['Movies Tonight ? ( :', []]
# ["Is it cricket season ? I've killed about 20 in the laundry room in the past week .", []]
# ["Is it cricket season ? I've killed about 20 in the laundry room in the past week .", []]
# ['Come to " 6th Biannual 24 Hour Prayer Focus " Saturday , November 13 from 10:00 am to 1:00 pm . Mark the Date !!! http://fb.me/JyYXPmql', []]
# ['Come to " 6th Biannual 24 Hour Prayer Focus " Saturday , November 13 from 10:00 am to 1:00 pm . Mark the Date !!! http://fb.me/JyYXPmql', []]
# ['A nigga not even startin tonight , they must be tryna get our bakc up QB hurt . smdh', []]
# ['A nigga not even startin tonight , they must be tryna get our bakc up QB hurt . smdh', []]
# ['Apparently 40 days , 1 hour , 49 mins and 36 seconds to Doha ....', [[13, 'location']]]
# ['Apparently 40 days , 1 hour , 49 mins and 36 seconds to Doha ....', [(56, 60, 'location')]]
# ["Having some coffee , the only way I'll make it through tonight .", []]
# ["Having some coffee , the only way I'll make it through tonight .", []]
# ['i wonder if our football team is gonna win their game today ...', []]
# ['i wonder if our football team is gonna win their game today ...', []]
# ['I hate it when i forget that i wear glasses&amp;i go to itch my eye&amp;i hit my glasses -_- . not cool', []]
# ['I hate it when i forget that i wear glasses&amp;i go to itch my eye&amp;i hit my glasses -_- . not cool', []]
# ['@SQicedragon How can I get the updates ? I created a login for it today , will it let me know automatically next time ?', []]
# ['@SQicedragon How can I get the updates ? I created a login for it today , will it let me know automatically next time ?', []]
# ['RT @GdnPolitics : RT @AlJahom : Blair : " I\'m gonna be the next Pope " Brown : " I won\'t stop you as long as you make sure it \'s my turn next "', [[6, 'person'], [14, 'person'], [16, 'person']]]
# ['RT @GdnPolitics : RT @AlJahom : Blair : " I\'m gonna be the next Pope " Brown : " I won\'t stop you as long as you make sure it \'s my turn next "', [(32, 37, 'person'), (64, 68, 'person'), (71, 76, 'person')]]
# ["I'll go get some #sleep before some #TGS #news , later everyone x ) !", []]
# ["I'll go get some #sleep before some #TGS #news , later everyone x ) !", []]
# ['An entire stack of papers has disappeared . I think that is a sign to wrap up for the week .', []]
# ['An entire stack of papers has disappeared . I think that is a sign to wrap up for the week .', []]
# ['Best day of school :) haha i want a popsycle : x', []]
# ['Best day of school :) haha i want a popsycle : x', []]
# ["@VicapherIsDaddy ilike to call it that too . I dnt knw why people talk hella sht over tha internet ' imean iadmit ibe qassin hoes when ..", []]
# ["@VicapherIsDaddy ilike to call it that too . I dnt knw why people talk hella sht over tha internet ' imean iadmit ibe qassin hoes when ..", []]
# ["Ball Gowns : Becoming the Belle of the Ball . It 's easy to shine like a star when you know some basic tricks . http://bit.ly/d4s9RR", []]
# ["Ball Gowns : Becoming the Belle of the Ball . It 's easy to shine like a star when you know some basic tricks . http://bit.ly/d4s9RR", []]
# ['dnce 2 day at skool 2 dau wuz kinda corny evn doe i dnce a lil bit ugh bored lke always whn is ya gurl neva nt trin 2 fin sunthn 2', []]
# ['dnce 2 day at skool 2 dau wuz kinda corny evn doe i dnce a lil bit ugh bored lke always whn is ya gurl neva nt trin 2 fin sunthn 2', []]
# ['Lmao . I have a feeling Imma get yelled at tomorrow . Big time . XD Ehh oh well', []]
# ['Lmao . I have a feeling Imma get yelled at tomorrow . Big time . XD Ehh oh well', []]
# ['n dude .... one of the new choir teacher that they interviewed ( we had him all week ) gave us DONUTS !!!! haha hes nice', []]
# ['n dude .... one of the new choir teacher that they interviewed ( we had him all week ) gave us DONUTS !!!! haha hes nice', []]
# ['RT @diggy_simmons : Last day ..... http://twitpic.com/2g9c1e', []]
# ['RT @diggy_simmons : Last day ..... http://twitpic.com/2g9c1e', []]
# ['RT @Quotealicious : Today , I saw a guy driving a Pepsi truck , drinking a Coke . MLIA #Quotealicious', [[11, 'corporation'], [16, 'product']]]
# ['RT @Quotealicious : Today , I saw a guy driving a Pepsi truck , drinking a Coke . MLIA #Quotealicious', [(50, 55, 'corporation'), (75, 79, 'product')]]
# ['After I pet a kitten on JFK , the owners informed me it \'s \' double-pawed \' ( polydactyl) , which is " a form of retardation in the animal kingdom "', [[6, 'person']]]
# ['After I pet a kitten on JFK , the owners informed me it \'s \' double-pawed \' ( polydactyl) , which is " a form of retardation in the animal kingdom "', [(24, 27, 'person')]]
# ['Oct 9 ( happy dance ) RT @MiChY_pEaChY @LiifeSizeDoll wens ur bdayy boo ??!!', []]
# ['Oct 9 ( happy dance ) RT @MiChY_pEaChY @LiifeSizeDoll wens ur bdayy boo ??!!', []]
# ['@joshHnumber1fan its okay then .. make it when it works :D', []]
# ['@joshHnumber1fan its okay then .. make it when it works :D', []]
# ['@iSUPPORTBIEBER IM SORRRRRRRRRRRRRRRRRRRRY &lt; /3 i have to go , her partys in a week and im on the dais !', []]
# ['@iSUPPORTBIEBER IM SORRRRRRRRRRRRRRRRRRRRY &lt; /3 i have to go , her partys in a week and im on the dais !', []]
# ['@xXLauraJXx ino i did tweet him b4 n justthen about kenny signing his book but it was today ive already missed it :(', [[8, 'person'], [10, 'person']]]
# ['@xXLauraJXx ino i did tweet him b4 n justthen about kenny signing his book but it was today ive already missed it :(', [(37, 45, 'person'), (52, 57, 'person')]]
# ['800 miles to see clients , 3 ACC candidate/commissioner meetings , big press release , making it to Friday .. PRICELESS !', []]
# ['800 miles to see clients , 3 ACC candidate/commissioner meetings , big press release , making it to Friday .. PRICELESS !', []]
# ['This is a battle song .. Brothers and sisters .. Time to go to war !', []]
# ['This is a battle song .. Brothers and sisters .. Time to go to war !', []]
# ['HAPPY B . DAY TORA *OOOOOOOOO* ~', []]
# ['HAPPY B . DAY TORA *OOOOOOOOO* ~', []]
# ["@shoeboxL Happy Birthday ! s/n what did I miss in Doc Lewis ' class today ? lol", [(10, 11, 'person')]]
# ["@shoeboxL Happy Birthday ! s/n what did I miss in Doc Lewis ' class today ? lol", [(50, 59, 'person')]]
# ['- FantasyPro . net offers a 100% Deposit Match and $5 in credits for each referral this week only ! Must deposit by 1pm ET Sunday Sept 19th .', []]
# ['- FantasyPro . net offers a 100% Deposit Match and $5 in credits for each referral this week only ! Must deposit by 1pm ET Sunday Sept 19th .', []]
# ['neck hurts and no time to schedule acupuncture and massage .', []]
# ['neck hurts and no time to schedule acupuncture and massage .', []]
# ["RT @justinbieber : RT @StephLeveridge @justinbieber i'm having a bad day :( Just a hi from you would turn it around( : Love you xxxxxxx = HI !", []]
# ["RT @justinbieber : RT @StephLeveridge @justinbieber i'm having a bad day :( Just a hi from you would turn it around( : Love you xxxxxxx = HI !", []]
# ["RT @mindykaling : When you wear your heart on your sleeve , make sure your shirt is f'ing dope .", []]
# ["RT @mindykaling : When you wear your heart on your sleeve , make sure your shirt is f'ing dope .", []]
# ["We're on the tall ship Silva tonight . Still a few tickets available . Rain is gone and we're getting ready to set sail . 1030 PM we depart", [(2, 5, 'location')]]
# ["We're on the tall ship Silva tonight . Still a few tickets available . Rain is gone and we're getting ready to set sail . 1030 PM we depart", [(9, 28, 'location')]]
# ['Hoyy One Day Lindooo Pero Un Touch De Aburrimiento : S', []]
# ['Hoyy One Day Lindooo Pero Un Touch De Aburrimiento : S', []]
# ['Playboy - 10 October 2010 Slovenia : Playboy - 10 October 2010 SloveniaSlovene | 138 pages | PDF | 39.45 Mb http://bit.ly/aJILb4', [[0, 'corporation'], [5, 'location'], [7, 'corporation']]]
# ['Playboy - 10 October 2010 Slovenia : Playboy - 10 October 2010 SloveniaSlovene | 138 pages | PDF | 39.45 Mb http://bit.ly/aJILb4', [(0, 7, 'corporation'), (26, 34, 'location'), (37, 44, 'corporation')]]
# ['RT @fresh_av8ted : Tonight ! " Sex In The City " Pt . 2 at #ZULA ! Hosted By : 30+ Beautiful Ladies ! [ PLz RT ]', [(6, 9, 'creative-work')]]
# ['RT @fresh_av8ted : Tonight ! " Sex In The City " Pt . 2 at #ZULA ! Hosted By : 30+ Beautiful Ladies ! [ PLz RT ]', [(31, 46, 'creative-work')]]
# ['RT @Slijterijmeisje : Kreeg net een bruikbare tip van iemand die vorige week was begonnen met een whiskydieet , hij was nu al 3 dagen kwijt', []]
# ['RT @Slijterijmeisje : Kreeg net een bruikbare tip van iemand die vorige week was begonnen met een whiskydieet , hij was nu al 3 dagen kwijt', []]
# ['Accounts Payable Coordinator North York - $37K ( 1 year Contract)Location : Toronto , Ontario , CANADA ... http://bit.ly/aOe78A #jobs', [(3, 4, 'location'), [12, 'location'], [14, 'location'], [16, 'location']]]
# ['Accounts Payable Coordinator North York - $37K ( 1 year Contract)Location : Toronto , Ontario , CANADA ... http://bit.ly/aOe78A #jobs', [(29, 39, 'location'), (76, 83, 'location'), (86, 93, 'location'), (96, 102, 'location')]]
# ['Spent all of last night puking , and all of today fretting . Some people totally fail to pick up the slack when you are away .', []]
# ['Spent all of last night puking , and all of today fretting . Some people totally fail to pick up the slack when you are away .', []]
# ['If you are in Belfast this weekend go to Botanic Gdns , for Taste N I , free food drink face painting etc . Should be good day out . Sat &amp; Sun', [[4, 'location'], (9, 10, 'location')]]
# ['If you are in Belfast this weekend go to Botanic Gdns , for Taste N I , free food drink face painting etc . Should be good day out . Sat &amp; Sun', [(14, 21, 'location'), (41, 53, 'location')]]
# ['overheard on subway ..." so when you run , do your elbows sweat ?"', []]
# ['overheard on subway ..." so when you run , do your elbows sweat ?"', []]
# ['But what happens when karam turns right around and bites you ? And everything you stand for turns on you despite you ?', []]
# ['But what happens when karam turns right around and bites you ? And everything you stand for turns on you despite you ?', []]
# ['Getting this head right for whateva I get into tonite #sittinupunderthedryertweet', []]
# ['Getting this head right for whateva I get into tonite #sittinupunderthedryertweet', []]
# ["Owner says its cool . Trying to get info on when they'll be back in town now @AandLClothingCo", []]
# ["Owner says its cool . Trying to get info on when they'll be back in town now @AandLClothingCo", []]
# ['Easy A tonight . WOOOO', []]
# ['Easy A tonight . WOOOO', []]
# ['Whats goin on ( in tally ) tonight twitter !!', [[8, 'corporation']]]
# ['Whats goin on ( in tally ) tonight twitter !!', [(35, 42, 'corporation')]]
# ['going now guiseeeee ... if i dont see you through the week ill see you through the window :) :)', []]
# ['going now guiseeeee ... if i dont see you through the week ill see you through the window :) :)', []]
# ['jus about to get dressed and leave again .... smh a very long day', []]
# ['jus about to get dressed and leave again .... smh a very long day', []]
# ['@klutzy_girl @ratherastory I wrote 74,000 words in February .', []]
# ['@klutzy_girl @ratherastory I wrote 74,000 words in February .', []]
# ['RT @davehodg : Pope says atheists pick &amp; choose their morals . Correct . Today I will be frowning on child abuse &amp; not having a problem wit ...', [[3, 'person']]]
# ['RT @davehodg : Pope says atheists pick &amp; choose their morals . Correct . Today I will be frowning on child abuse &amp; not having a problem wit ...', [(15, 19, 'person')]]
# ["Sunday can you please hurry up and get here already ?! I want to see @nickjonas @kevinjonas @joejonas already ! Concert 's going to be rad ! :P", []]
# ["Sunday can you please hurry up and get here already ?! I want to see @nickjonas @kevinjonas @joejonas already ! Concert 's going to be rad ! :P", []]
# ["VMAs . ( : I control my own life , Charles was never in charge !! It 's def one of THOSE days . Haha", [[10, 'person']]]
# ["VMAs . ( : I control my own life , Charles was never in charge !! It 's def one of THOSE days . Haha", [(35, 42, 'person')]]
# ['@samanthaaai Up super duper early next week : |', []]
# ['@samanthaaai Up super duper early next week : |', []]
# ['FRIDAY Sept . 17 http://goo.gl/fb/83ib3', []]
# ['FRIDAY Sept . 17 http://goo.gl/fb/83ib3', []]
# ['#blackholidays " National forget the he say she say ... what do God say day "', [[12, 'person']]]
# ['#blackholidays " National forget the he say she say ... what do God say day "', [(64, 67, 'person')]]
# ["@speedy1013 I ain't seen them !! Hmm maybe have to download next time we have a movie night here . Zombies are badass !", []]
# ["@speedy1013 I ain't seen them !! Hmm maybe have to download next time we have a movie night here . Zombies are badass !", []]
# ['Beautiful day in Chicago ! Nice to get away from the Florida heat .', [[3, 'location'], [11, 'location']]]
# ['Beautiful day in Chicago ! Nice to get away from the Florida heat .', [(17, 24, 'location'), (53, 60, 'location')]]
# ["Oscar 's new favorite pass time is running as fast as he can from one end of the house to another yelling BuhBYYYYYE", [[0, 'person']]]
# ["Oscar 's new favorite pass time is running as fast as he can from one end of the house to another yelling BuhBYYYYYE", [(0, 5, 'person')]]
# ['RT @geriatricus : May we all reflect on the workings of our hearts , and in our acts , with our Jewish friends and loved ones at the cusp o ...', []]
# ['RT @geriatricus : May we all reflect on the workings of our hearts , and in our acts , with our Jewish friends and loved ones at the cusp o ...', []]
# ['@iDame2Please yea u c da pic 1st Presbyterian all day lol', [(6, 7, 'group')]]
# ['@iDame2Please yea u c da pic 1st Presbyterian all day lol', [(29, 45, 'group')]]
# ['This next question , may take a few moments to research . BUT the answer IS on JavaMonkeys . com . So , we will pick a ... http://fb.me/GTRhPujh', []]
# ['This next question , may take a few moments to research . BUT the answer IS on JavaMonkeys . com . So , we will pick a ... http://fb.me/GTRhPujh', []]
# ['Jan Brewer : Beheadings ? http://bit.ly/a2LBMP', [(0, 1, 'person')]]
# ['Jan Brewer : Beheadings ? http://bit.ly/a2LBMP', [(0, 10, 'person')]]
# ['@EnticeMeBaby Well that makes sense . When you have real life trauma , it can often drain your energy &amp; you just withdraw into yourself . I do .', []]
# ['@EnticeMeBaby Well that makes sense . When you have real life trauma , it can often drain your energy &amp; you just withdraw into yourself . I do .', []]
# ["@mekamoe927 I've had one before , but it was a short experience ( double entendre intended) .", []]
# ["@mekamoe927 I've had one before , but it was a short experience ( double entendre intended) .", []]
# ['Tonight , dinner with friends &lt; 3', []]
# ['Tonight , dinner with friends &lt; 3', []]
# ["Man I swear I bought 2 new outfits but it 's cold them dresses not gettin worn today ....", []]
# ["Man I swear I bought 2 new outfits but it 's cold them dresses not gettin worn today ....", []]
# ["A Hughie O'Donoghue painting , some great curvy pots and intricately illuminated Persian books .. time well spent in the Fitzwilliam .", [(1, 2, 'person'), (19, 20, 'location')]]
# ["A Hughie O'Donoghue painting , some great curvy pots and intricately illuminated Persian books .. time well spent in the Fitzwilliam .", [(2, 19, 'person'), (117, 132, 'location')]]
# ['Greek Festival at St Johns before ASPEN', [(3, 4, 'location'), [6, 'location']]]
# ['Greek Festival at St Johns before ASPEN', [(18, 26, 'location'), (34, 39, 'location')]]
# ['@BeliebinMinajj OMG MILLIONS it was on repeat yesterday all day till my last lesson and then around 9pm i put it back and then its been on', []]
# ['@BeliebinMinajj OMG MILLIONS it was on repeat yesterday all day till my last lesson and then around 9pm i put it back and then its been on', []]
# ['If you are staying in Gainesville , come check out Costa Lounge TONIGHT ! Say you are with salsa caliente and get in ... http://fb.me/FZVzm8H9', [[5, 'location'], (10, 11, 'location'), (18, 19, 'person')]]
# ['If you are staying in Gainesville , come check out Costa Lounge TONIGHT ! Say you are with salsa caliente and get in ... http://fb.me/FZVzm8H9', [(22, 33, 'location'), (51, 63, 'location'), (91, 105, 'person')]]
# ['I think one of the coolest things to do would be to hang out with the Rza for a day .', [(15, 16, 'person')]]
# ['I think one of the coolest things to do would be to hang out with the Rza for a day .', [(66, 73, 'person')]]
# ['Going on a &amp;#39 ;d ate&amp;#39 ; with Whitney tonight , :P . Haha .', [[8, 'person']]]
# ['Going on a &amp;#39 ;d ate&amp;#39 ; with Whitney tonight , :P . Haha .', [(42, 49, 'person')]]
# ["Day three of St John 's wort tea for anxiety . So far today I havent had a panic attack...we'll see if this works !", []]
# ["Day three of St John 's wort tea for anxiety . So far today I havent had a panic attack...we'll see if this works !", []]
# ['is at Home-Going Well - I take a Break-Online Saturday 4:30 pm- 6:00 pm ET- Good Day- Good Night-Good Week-End !!!', []]
# ['is at Home-Going Well - I take a Break-Online Saturday 4:30 pm- 6:00 pm ET- Good Day- Good Night-Good Week-End !!!', []]
# ["Ugh I DON'T HAVE MY EARPHONES I GUESS I WON'T B TALKING AND DRIVING TODAY LOL .... Excuses Excuses Excuses SMH", []]
# ["Ugh I DON'T HAVE MY EARPHONES I GUESS I WON'T B TALKING AND DRIVING TODAY LOL .... Excuses Excuses Excuses SMH", []]
# ['Now off for Sushi before Sundown', []]
# ['Now off for Sushi before Sundown', []]
# ['@GhostAdventures Did you know ur new season starts tonight ? jk The best paranormal show #Ghostadventures !', []]
# ['@GhostAdventures Did you know ur new season starts tonight ? jk The best paranormal show #Ghostadventures !', []]
# ['There was just a fire at work . Today is looking up .', []]
# ['There was just a fire at work . Today is looking up .', []]
# ["man , why you have to grill under my AC unit . *turns it off* On a happier note , IT'S BBQ TIME .", []]
# ["man , why you have to grill under my AC unit . *turns it off* On a happier note , IT'S BBQ TIME .", []]
# ['Katie up 6-0 after 1st', [[0, 'person']]]
# ['Katie up 6-0 after 1st', [(0, 5, 'person')]]
# ...
# ['Happy New Year to all . May the year bring peace joy and love . May our societal advancement catch up to our technological ones .', []]
# ['Happy New Year to all . May the year bring peace joy and love . May our societal advancement catch up to our technological ones .', []]
# ["Can't wait till Friday now .. ughhh", []]
# ["Can't wait till Friday now .. ughhh", []]
# ['Will Shawn Mendez be opening up for taylor swift in September ? @SprintCenter', [(1, 2, 'person'), (7, 8, 'person')]]
# ['Will Shawn Mendez be opening up for taylor swift in September ? @SprintCenter', [(5, 17, 'person'), (36, 48, 'person')]]
# ['" Maybe I can do this . Maybe I\'m stronger than I think ." @JaimePrimak #Cawfeetawk #Wednesday ... http://t.co/wIsDAcRjXQ', []]
# ['" Maybe I can do this . Maybe I\'m stronger than I think ." @JaimePrimak #Cawfeetawk #Wednesday ... http://t.co/wIsDAcRjXQ', []]
# ['Sunday Roundup - Huffington Post http://t.co/agNWEPYP9K #Science http://t.co/SC5FgVXEue', [(3, 4, 'corporation')]]
# ['Sunday Roundup - Huffington Post http://t.co/agNWEPYP9K #Science http://t.co/SC5FgVXEue', [(17, 32, 'corporation')]]
# ['RT @GreatLengthsUK : Party season is most definitely in full swing ! We &lt; 3 wavy this look for a #Saturday night http://t.co/7pDTctw47h', []]
# ['RT @GreatLengthsUK : Party season is most definitely in full swing ! We &lt; 3 wavy this look for a #Saturday night http://t.co/7pDTctw47h', []]
# ['If I were to leave this place tomorrow , would you try and make me stay ? Would you beg for me to stay ?', []]
# ['If I were to leave this place tomorrow , would you try and make me stay ? Would you beg for me to stay ?', []]
# ['December 16 , 2014 at 01:05 AM post5sdf', []]
# ['December 16 , 2014 at 01:05 AM post5sdf', []]
# ['RT @ZaddyA__ : All u going to see tomorrow at school http://t.co/x8ZNPly7OR', []]
# ['RT @ZaddyA__ : All u going to see tomorrow at school http://t.co/x8ZNPly7OR', []]
# ["RT @yoteens : Realizing tomorrow is Monday but there 's no class http://t.co/huFBr3YCoR", []]
# ["RT @yoteens : Realizing tomorrow is Monday but there 's no class http://t.co/huFBr3YCoR", []]
# ['@LovableAshIrwin hahaha oohh , sorry . I was studying for a tests :) I have them tomorrow', []]
# ['@LovableAshIrwin hahaha oohh , sorry . I was studying for a tests :) I have them tomorrow', []]
# ["RT @McClain_on_NFL : I can't criticize Keenum considering he hasn't throw a pass since last season and was on Rams ' P squad Sunday .", [[6, 'person'], [19, 'group']]]
# ["RT @McClain_on_NFL : I can't criticize Keenum considering he hasn't throw a pass since last season and was on Rams ' P squad Sunday .", [(39, 45, 'person'), (110, 114, 'group')]]
# ['RT @wisatatiketcom : PROMO Pontianak-Ketapang , Jan 2015 . klik http://t.co/0ddm1nju1P http://t.co/OH3DKpx5GI', []]
# ['RT @wisatatiketcom : PROMO Pontianak-Ketapang , Jan 2015 . klik http://t.co/0ddm1nju1P http://t.co/OH3DKpx5GI', []]
# ['#Deals #82 http://t.co/3YSnDYVuck 72F7210 9556 RISER BOARD WITH WARRANTY via eBay_US $ 50.00 End Date : Sunday F ... http://t.co/v8zcEV5Lzk', [(3, 6, 'product')]]
# ['#Deals #82 http://t.co/3YSnDYVuck 72F7210 9556 RISER BOARD WITH WARRANTY via eBay_US $ 50.00 End Date : Sunday F ... http://t.co/v8zcEV5Lzk', [(34, 58, 'product')]]
# ['RT @youurleaders : 9700 mon doudou &lt; 3', []]
# ['RT @youurleaders : 9700 mon doudou &lt; 3', []]
# ['Marco Belinelli is OUT for the #Spurs tonight - #DFS @Fanduel NBA - Saturday 1/31/15 - http://t.co/YUzvy3gAWR', [(0, 1, 'person'), [6, 'group']]]
# ['Marco Belinelli is OUT for the #Spurs tonight - #DFS @Fanduel NBA - Saturday 1/31/15 - http://t.co/YUzvy3gAWR', [(0, 15, 'person'), (31, 37, 'group')]]
# ['RT @OurGEJ : If we #FailBuhari this February , we would have sent a clear message to those who want to take Nigeria back to the dark ages !', [[22, 'location']]]
# ['RT @OurGEJ : If we #FailBuhari this February , we would have sent a clear message to those who want to take Nigeria back to the dark ages !', [(108, 115, 'location')]]
# ['FGCU @ UNF tomorrow night at 7PM at UNF Arena . Come out , watch some basketball , drink some beer and cheer on @OspreyMBB ! #SWOOP', [[0, 'group'], [2, 'group'], (8, 9, 'location')]]
# ['FGCU @ UNF tomorrow night at 7PM at UNF Arena . Come out , watch some basketball , drink some beer and cheer on @OspreyMBB ! #SWOOP', [(0, 4, 'group'), (7, 10, 'group'), (36, 45, 'location')]]
# ['RT @_iiViolet : I really need a day between Saturday and Sunday .', []]
# ['RT @_iiViolet : I really need a day between Saturday and Sunday .', []]
# ['How Did We Find the Distance to the Sun ? http://t.co/Ouq8nMtyWa', []]
# ['How Did We Find the Distance to the Sun ? http://t.co/Ouq8nMtyWa', []]
# ['Road Conditions as of 6:41 AM CST Tuesday #NDWX http://t.co/hx0k1iUyOW', []]
# ['Road Conditions as of 6:41 AM CST Tuesday #NDWX http://t.co/hx0k1iUyOW', []]
# ["RT @509pilots : If you want to dance tomorrow night , Rays is the spot man i'm telling you . Ask ya momma she know #Topp", [[11, 'location']]]
# ["RT @509pilots : If you want to dance tomorrow night , Rays is the spot man i'm telling you . Ask ya momma she know #Topp", [(54, 58, 'location')]]
# ['RT @jvsk3 : Kiran Bedi d 1st person to misuse home guards , she should 1st set the example ? http://t.co/oncWtyGqXB', [(3, 4, 'person')]]
# ['RT @jvsk3 : Kiran Bedi d 1st person to misuse home guards , she should 1st set the example ? http://t.co/oncWtyGqXB', [(12, 22, 'person')]]
# ['RT @VansWarpedTour : FIVE more 2015 #vanswarpedtour artists to be announced this Wednesday at 4PM PST / 7PM EST http://t.co/emBQWmAdnz', []]
# ['RT @VansWarpedTour : FIVE more 2015 #vanswarpedtour artists to be announced this Wednesday at 4PM PST / 7PM EST http://t.co/emBQWmAdnz', []]
# ["Started and finished a book today . I'd say that 's a successful Saturday !", []]
# ["Started and finished a book today . I'd say that 's a successful Saturday !", []]
# ["NY Congressman Michael Grimm , who pleaded guilty to tax evasion , says he'll resign Jan . 5 : http://t.co/C1JO2LGEbR", [[0, 'location'], (2, 3, 'person')]]
# ["NY Congressman Michael Grimm , who pleaded guilty to tax evasion , says he'll resign Jan . 5 : http://t.co/C1JO2LGEbR", [(0, 2, 'location'), (15, 28, 'person')]]
# ['Tomorrow ( 1/31) , FREE show at @SPSMarket w/ POUNDERS (@PNDRS ) + MAKING MOVIES (@mkngmvs ) 7pm Daydream Nation Vol . 34 : https://t.co/0SC9flGRan', []]
# ['Tomorrow ( 1/31) , FREE show at @SPSMarket w/ POUNDERS (@PNDRS ) + MAKING MOVIES (@mkngmvs ) 7pm Daydream Nation Vol . 34 : https://t.co/0SC9flGRan', []]
# ['@TL_jp January 25 , 2015 at 01:19 AM http://t.co/QmEFdcJ013', []]
# ['@TL_jp January 25 , 2015 at 01:19 AM http://t.co/QmEFdcJ013', []]
# ['@JOID_Aoi ah .. :( ntar may ditarok dipojok / ?', []]
# ['@JOID_Aoi ah .. :( ntar may ditarok dipojok / ?', []]
# ['RT @MgaPinoyPatama : Buti pa ang 8888 , marunong magsorry at may explanation pa . Eh ikaw ? #MidnightHugot', []]
# ['RT @MgaPinoyPatama : Buti pa ang 8888 , marunong magsorry at may explanation pa . Eh ikaw ? #MidnightHugot', []]
# ['OSU should give us tomorrow off so we can all get buckeye wasted in celebration of the game . #amirite ?', [[0, 'group']]]
# ['OSU should give us tomorrow off so we can all get buckeye wasted in celebration of the game . #amirite ?', [(0, 3, 'group')]]
# ['Photos : President Jonathan Visits Olu of Warri &amp; Pastor Ayo Oritsejafor : President Goodluck Jonathan on Friday ... http://t.co/wCaxcV7WMx', [(2, 3, 'person'), (5, 7, 'person'), (10, 11, 'person'), (14, 15, 'person')]]
# ['Photos : President Jonathan Visits Olu of Warri &amp; Pastor Ayo Oritsejafor : President Goodluck Jonathan on Friday ... http://t.co/wCaxcV7WMx', [(9, 27, 'person'), (35, 47, 'person'), (61, 76, 'person'), (89, 106, 'person')]]
# ['DNA YEAR AND SALE DI STORE KARAWACI SAMPAI TANGGAL 15 JAN 2015 DAN DNA PITSTOP SEKTOR 1 SAMPAI 25 JAN 2015 . For buy one get one free !', []]
# ['DNA YEAR AND SALE DI STORE KARAWACI SAMPAI TANGGAL 15 JAN 2015 DAN DNA PITSTOP SEKTOR 1 SAMPAI 25 JAN 2015 . For buy one get one free !', []]
# ['RT @om : Jan Koum says @whatsapp now has 700 million messaging ! Cool https://t.co/sKcZuyUeUp', [(3, 4, 'person')]]
# ['RT @om : Jan Koum says @whatsapp now has 700 million messaging ! Cool https://t.co/sKcZuyUeUp', [(9, 17, 'person')]]
# ['#Marriott to reach 1M rooms in 2015 , but sees risk from concerns over terrorism - http://t.co/REVbmFHQFv #finance $MAR #travel', [[0, 'corporation']]]
# ['#Marriott to reach 1M rooms in 2015 , but sees risk from concerns over terrorism - http://t.co/REVbmFHQFv #finance $MAR #travel', [(0, 9, 'corporation')]]
# ['#Denver : Guster Live in Concert at Ogden Theatre - Jan 17 More Info : http://t.co/8K9cMMnPxP', [[0, 'location'], [2, 'group'], (7, 8, 'location')]]
# ['#Denver : Guster Live in Concert at Ogden Theatre - Jan 17 More Info : http://t.co/8K9cMMnPxP', [(0, 7, 'location'), (10, 16, 'group'), (36, 49, 'location')]]
# ['Selamat Pagi happy friday Anak negeri .. Semangat pagi ini bersama @bratasaragih @aiy_guvee di #BERTENGGER', []]
# ['Selamat Pagi happy friday Anak negeri .. Semangat pagi ini bersama @bratasaragih @aiy_guvee di #BERTENGGER', []]
# ['RT @VickiEngland74 : Seems a typical Saturday afternoon for the @1874Northwich boys . Training !! http://t.co/RxuG93jtMP', []]
# ['RT @VickiEngland74 : Seems a typical Saturday afternoon for the @1874Northwich boys . Training !! http://t.co/RxuG93jtMP', []]
# ["Going to be out for surgery until Wednesday , but I can't wait to see you all !", []]
# ["Going to be out for surgery until Wednesday , but I can't wait to see you all !", []]
# ['Thanks #Bengals #Patriots Clinch 1st Seed And Home Field For AFC #Playoffs #AFCGoesThroughGillette #PatsNation', [[1, 'group'], [2, 'group'], [10, 'group']]]
# ['Thanks #Bengals #Patriots Clinch 1st Seed And Home Field For AFC #Playoffs #AFCGoesThroughGillette #PatsNation', [(7, 15, 'group'), (16, 25, 'group'), (61, 64, 'group')]]
# ['ahora llorame un mar ...', []]
# ['ahora llorame un mar ...', []]
# ['Curious to see who City buy in January . They need a striker desperately .', [[4, 'group']]]
# ['Curious to see who City buy in January . They need a striker desperately .', [(19, 23, 'group')]]
# ["%20 DISCOUNT ON ALL GRADE DENTAL'S THIS FEBRUARY ! MAKE YOUR APPOINTMENT TODAY ! OUR SCHEDULE IS FILLING UP ... http://t.co/OT8YSZhfNK", []]
# ["%20 DISCOUNT ON ALL GRADE DENTAL'S THIS FEBRUARY ! MAKE YOUR APPOINTMENT TODAY ! OUR SCHEDULE IS FILLING UP ... http://t.co/OT8YSZhfNK", []]
# ['50% OFF - RESERVATION FEE ( until January 31 , 2015 ) Located at Brgy . Lantic , Carmona , Cavite Near Alabang and ... http://t.co/ixEvz5hVxI', [[14, 'location'], [16, 'location'], [18, 'location'], [20, 'location'], [22, 'location']]]
# ['50% OFF - RESERVATION FEE ( until January 31 , 2015 ) Located at Brgy . Lantic , Carmona , Cavite Near Alabang and ... http://t.co/ixEvz5hVxI', [(65, 69, 'location'), (72, 78, 'location'), (81, 88, 'location'), (91, 97, 'location'), (103, 110, 'location')]]
# ["@knbrmurph Don't forget the heinous bathroom brawl , too hot for 3rd qtr attendance , and my favorite - @JedYork famous tweet on the Jumbotron", []]
# ["@knbrmurph Don't forget the heinous bathroom brawl , too hot for 3rd qtr attendance , and my favorite - @JedYork famous tweet on the Jumbotron", []]
# ['Tomorrow I have class for 12 hours I hate Wednesdays so much #psillprobsaythiseveryweek', []]
# ['Tomorrow I have class for 12 hours I hate Wednesdays so much #psillprobsaythiseveryweek', []]
# ['Photo : GamePro #142 , July 2000 . A preview of Tekken Tag Tournament on the PS2 ! Follow OldGameMags on ... http://t.co/LSUGkhiyM8', [(11, 13, 'creative-work'), [16, 'product']]]
# ['Photo : GamePro #142 , July 2000 . A preview of Tekken Tag Tournament on the PS2 ! Follow OldGameMags on ... http://t.co/LSUGkhiyM8', [(48, 69, 'creative-work'), (77, 80, 'product')]]
# ['I get paid tomorrow PARTY AT GOODWILL', []]
# ['I get paid tomorrow PARTY AT GOODWILL', []]
# ['@deanna_gussette algood :D . Goodluck for tomorrow', []]
# ['@deanna_gussette algood :D . Goodluck for tomorrow', []]
# ['4th street " @_MsGuxx : Uphuzani ? RT @Gucci_ReLoaded : That thing gives me chest pains hey " MsGuxx : A guareezy would be lovely rn ""', []]
# ['4th street " @_MsGuxx : Uphuzani ? RT @Gucci_ReLoaded : That thing gives me chest pains hey " MsGuxx : A guareezy would be lovely rn ""', []]
# ["I don't like to be stuck at home all day on a saturday", []]
# ["I don't like to be stuck at home all day on a saturday", []]
# ['The Lip Sync Battle during the After Party is going to be epic Thursday night . Bring it on . http://t.co/mqSP0h1wob', []]
# ['The Lip Sync Battle during the After Party is going to be epic Thursday night . Bring it on . http://t.co/mqSP0h1wob', []]
# ['RT @JoshDevineDrums : Get to see @HollyFarnworth tomorrow ! Excited !!!!', []]
# ['RT @JoshDevineDrums : Get to see @HollyFarnworth tomorrow ! Excited !!!!', []]
# ['Pantagraph : The overnight low Tuesday is expected to drop to -5 degrees with wind chill valu ... http://t.co/OOGIHhzVzt', []]
# ['Pantagraph : The overnight low Tuesday is expected to drop to -5 degrees with wind chill valu ... http://t.co/OOGIHhzVzt', []]
# ['Interesting that a 3rd Russian general " committed suicide " all within 8 months . Something strange is going on , maybe the pay wasn\'t good ...', []]
# ['Interesting that a 3rd Russian general " committed suicide " all within 8 months . Something strange is going on , maybe the pay wasn\'t good ...', []]
# ['" @Mackenzie_71 : Super Bowl Sunday "', []]
# ['" @Mackenzie_71 : Super Bowl Sunday "', []]
# ['Watch Barrow - Boston United Live December 20 , 2014 http://t.co/ONjbJOGROS', [[1, 'group'], (3, 4, 'group')]]
# ['Watch Barrow - Boston United Live December 20 , 2014 http://t.co/ONjbJOGROS', [(6, 12, 'group'), (15, 28, 'group')]]
# ["RT @harrygifsss : when u realize schools tomorrow and u haven't started ur hw http://t.co/gfLoPsz2BH", []]
# ["RT @harrygifsss : when u realize schools tomorrow and u haven't started ur hw http://t.co/gfLoPsz2BH", []]
# ['@null http://t.co/3O3Z3xyNC0 December 25 , 2014 at 02:44 PM Ver . kvx7', []]
# ['@null http://t.co/3O3Z3xyNC0 December 25 , 2014 at 02:44 PM Ver . kvx7', []]
# ['On January 22nd , from 11- 1.30 , TVPS will be offering free 60 second HIV Testing . This is a really important habit ... http://t.co/GXg82y7Hw4', [[8, 'location']]]
# ['On January 22nd , from 11- 1.30 , TVPS will be offering free 60 second HIV Testing . This is a really important habit ... http://t.co/GXg82y7Hw4', [(34, 38, 'location')]]
# ['Found this cool photo , not mine Love this guy more than words can describe !! ( : decorating the fire truck Friday ... http://t.co/Ov8l77dsFI', []]
# ['Found this cool photo , not mine Love this guy more than words can describe !! ( : decorating the fire truck Friday ... http://t.co/Ov8l77dsFI', []]
# ['Conditioning plan all made up for tomorrow , final touches have been made !! #softballready', []]
# ['Conditioning plan all made up for tomorrow , final touches have been made !! #softballready', []]
# ['Sat Jan 10 2015 12:46 : 39 GMT+0000 ( UTC )', []]
# ['Sat Jan 10 2015 12:46 : 39 GMT+0000 ( UTC )', []]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-8736cdda55ce> in <module>
# ----> 1 TRAIN_DATA = create_entities_char_level(text_train)
#       2 EVAL_DATA = create_entities_char_level(text_test)
#
# <ipython-input-117-e4a96d5a2224> in create_entities_char_level(text)
#     107
#     108     res = [str_i_to_char_i(x) for x in res]
# --> 109     res = [to_spacy_format(x) for x in res]
#     110     return res
#
# <ipython-input-117-e4a96d5a2224> in <listcomp>(.0)
#     107
#     108     res = [str_i_to_char_i(x) for x in res]
# --> 109     res = [to_spacy_format(x) for x in res]
#     110     return res
#
# <ipython-input-117-e4a96d5a2224> in to_spacy_format(sent_label)
#      86
#      87 def to_spacy_format(sent_label):
# ---> 88     sent = sent_label[0]
#      89     labels = sent_label[1]
#      90     res_dict = {'entities': labels}
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # TRAIN

# %%
import random
import spacy
model = None
n_iter=30

if model is not None:
    nlp1 = spacy.load(model)  # load existing spaCy model
    print("Loaded model '%s'" % model)
else:
    nlp1 = spacy.blank('en')  # create blank Language class
    print("Created blank 'en' model")

#create the built-in pipeline components and add them to the pipeline
# nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp1.pipe_names:
    print("Add ner pipe")
    ner = nlp1.create_pipe('ner')
    nlp1.add_pipe(ner, last=True)
# otherwise, get it so we can add labels

else:
    ner = nlp1.get_pipe('ner')
# Out:
# Created blank 'en' model
# Add ner pipe

# %%
# add labels, Trains data based on annotations 
for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# %%
def getTime(start,end):
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    time_since_start = "Time:  {:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds)
    return time_since_start

# %%
def log(start,i,len_):
    tenth = int(len_/20)
    if(i % tenth == 0):
        percent = int(round((i/len_*10),0))
        time_ = getTime(start,time.time())
        print("0%" + "=" *percent + str(percent*10) + "%, " + time_, end="\r" )

# %%
from tqdm import tqdm
from spacy.util import decaying
import time
# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp1.pipe_names if pipe != 'ner']
dropout = decaying(0.6, 0.2, 1e-4)
n_iter=4

with nlp1.disable_pipes(*other_pipes):  # only train NER
    #optimizer = nlp1.begin_training()
    optimizer.alpha = 0.0001
    losses = {}
    for itn in range(n_iter):
        random.shuffle(TRAIN_DATA)
        drop = next(dropout)
        start = time.time()
        for i,data in enumerate(TRAIN_DATA):
            log(start,i,len(TRAIN_DATA))
            text, annotations = data
            nlp1.update(
                [text],  # batch of texts
                [annotations],  # batch of annotations
                drop=0.5,  # dropout 
                sgd=optimizer,  # callable to update weights
                losses=losses)
            
        print(losses)
# Out:
# {'ner': 4030.179368534605}0:01:58.74
# {'ner': 8090.263954239019}0:01:56.44
# {'ner': 12081.728638740553}:01:53.49
# {'ner': 16083.479693405628}:02:08.47

# %% [markdown]
# # EVALUATION

# %%
def stanf_to_conLL(label):
    if (label == 'GPE' or label=='FAC'):
        return 'location'
    elif(label=='PERSON'):
        return 'person'
    elif(label=='PRODUCT'):
        return 'product'    
    elif(label=='ORG' or label=='NORP'):
        return 'group'
    elif(label=='WORK_OF_ART'):
        return ' creative-work'

# %%
def stanf_to_conLL(label):
    if (label == 'GPE' or label=='FAC'):
        return 'location'
    elif(label=='PERSON'):
        return 'person'
    elif(label=='PRODUCT'):
        return 'product'    
    elif(label=='ORG' or label=='NORP'):
        return 'group'
    elif(label=='WORK_OF_ART'):
        return ' creative-work'

# %%
def filter_entities(entities):
    ent = entities['entities']
    new_ents = [x for x in ent if x[2] in ['location','person','group','creative-work'
                                           ,'product']]
    entities['entities'] = new_ents
    return entities

# %%
def flair_to_spacy(dict_):
    res = []
    entities = dict_['entities']
    for ent in entities:
        text = ent['text']
        start_pos = ent['start_pos']
        end_pos = ent['end_pos']        
        label = ent['labels'][0].value
        if (label in accepted_ents):
            label = stanf_to_conLL(label)
            res.append((start_pos,end_pos,label))
    return res

# %%
import operator
def add_tuple(t1,t2):
    return tuple(map(operator.add, t1,t2))

# %%
import stanza
from flair.models import SequenceTagger
from spacy_stanza import StanzaLanguage
import spacy spacy.prefer_gpu()

snlp = stanza.Pipeline(lang="en",processors='tokenize,ner')
nlp_stanford = StanzaLanguage(snlp)    
tagger = SequenceTagger.load('ner-ontonotes')
accepted_ents = ['GPE', 'PERSON','ORG','FAC','WORK_OF_ART','NORP','PRODUCT']
# Out:
# 2020-06-02 15:53:40 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | ner       | ontonotes |
# =========================
#
# 2020-06-02 15:53:40 INFO: Use device: cpu
# 2020-06-02 15:53:40 INFO: Loading: tokenize
# 2020-06-02 15:53:40 INFO: Loading: ner
# 2020-06-02 15:53:40 INFO: Done loading processors!
# 2020-06-02 15:53:40,877 loading file /home/c3dric/.flair/models/en-ner-ontonotes-v0.4.pt

# %%
def evaluate_entitities(predicted_entities, correct_entities):
    correct_entities = set(correct_entities)
    predicted_entities = set(predicted_entities)    
    tp = len(correct_entities.intersection(predicted_entities))
    fp = len(predicted_entities - correct_entities)
    fn = len(correct_entities - predicted_entities)
    return fp,fn,tp

# %%
def evaluate(score):
    fp_global = score[0]
    fn_global = score[1]
    tp_global = score[2]
    
    # Avoid division by 0
    if(tp_global + fp_global ==0):
        precision =0
    else:
        precision = tp_global/(tp_global + fp_global) 
    
    # Avoid division by 0
    if(tp_global + fn_global ==0):
        recall = 0 
    else:
        recall= tp_global/ (tp_global + fn_global)
    
    # Avoid division by 0
    if(precision+recall == 0):
        f1_score = 0
    else:    
        f1_score = 2* ((precision*recall)/(precision+recall))
        
    result = defaultdict(float)
    result['recall'] = round(recall,2)
    result['f1'] = round(f1_score,2)
    result['precision'] = round(precision,2)
    return result

# %%
from flair.data import Sentence
from tqdm.notebook import tqdm
from collections import defaultdict
# Index 0 = fp, 1= fn and 2 = tp
eval_spacy = (0,0,0)
eval_stanza = (0,0,0)
eval_flair = (0,0,0)

for text,entities in tqdm(EVAL_DATA[0:5]):
    #Spacy Prediction
    spacy_stanford_correct_ents = [(text[x[0]:x[1]], x[2]) for x in entities['entities']]
    doc = nlp1(text)
    predicted_entities = [(ent.text, ent.label_) for ent in doc.ents]
    res_spacy = evaluate_entitities(predicted_entities,spacy_stanford_correct_ents)
    eval_spacy = add_tuple(eval_spacy,res_spacy)
    
    # Stanford Prediction
    entities = filter_entities(entities)
    spacy_stanford_correct_ents = [(text[x[0]:x[1]], x[2]) for x in entities['entities']]
    doc = nlp_stanford(text)
    predicted_entities = [(ent.text, ent.label_) for ent in doc.ents]
    predicted_entities = [x for x in predicted_entities if x[1] in accepted_ents]
    predicted_entities = [(x[0],stanf_to_conLL(x[1])) for x in predicted_entities ]
    res_stanza = evaluate_entitities(predicted_entities,spacy_stanford_correct_ents)
    eval_stanza = add_tuple(eval_stanza,res_stanza)
    
    # Flair Prediction
    sentence = Sentence(text)
    tagger.predict(sentence)
    dict_ = (sentence.to_dict(tag_type='ner'))
    predicted_entities = flair_to_spacy(dict_)
    ent_as_list = list(entities.values())[0]
    correct_entities = ent_as_list
    res_flair = evaluate_entitities(predicted_entities,correct_entities)
    eval_flair = add_tuple(eval_flair,res_flair)
    
    # Evaluation
    res_spacy = evaluate(eval_spacy)
    res_stanza = evaluate(eval_stanza)
    res_flair = evaluate(eval_flair)
    
    # Print results 
    pretty_print = "F1 scores -> Spacy: {}, Stanza: {}, Flair: {}".format(res_spacy['f1'],
                                                          res_stanza['f1'],res_flair['f1']) 

    
    
    print(pretty_print, end="\r" )
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# F1 scores -> Spacy: 0.25, Stanza: 0.57, Flair: 0.75
